# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('C:/data_science/gridcomputing/Modified_dataset_20001.csv')

# %%
corr=df.corr()

# %%
print(corr)
# Out:
#                        JobID  SubmitTime  WaitTime  RunTime     NProcs  \
# JobID               1.000000    0.991315 -0.034580  0.003258  0.233946
# SubmitTime          0.991315    1.000000 -0.039913  0.002045  0.242915
# WaitTime           -0.034580   -0.039913  1.000000  0.088022  0.019177
# RunTime             0.003258    0.002045  0.088022  1.000000  0.149922
# NProcs              0.233946    0.242915  0.019177  0.149922  1.000000
# AverageCPUTimeUsed  0.001529   -0.001129  0.084616  0.930096  0.149645
# Used Memory        -0.006505   -0.011825  0.053763  0.153102  0.201257
# ReqNProcs                NaN         NaN       NaN       NaN       NaN
# ReqTime             0.228093    0.239836 -0.011237  0.302292  0.514302
# ReqMemory          -0.015313   -0.036476  0.038418 -0.051670  0.088099
# Status             -0.253427   -0.259337 -0.017893 -0.130025 -0.872220
# UserID             -0.041675   -0.047152  0.050381 -0.005569  0.255266
# GroupID             0.166848    0.173612  0.013633  0.088784  0.568508
# ExecutableID        0.244308    0.251795  0.015525  0.129397  0.945138
# QueueID            -0.024557   -0.019680  0.002137  0.262011  0.045126
# PartitionID              NaN         NaN       NaN       NaN       NaN
# OrigSiteID          0.036718    0.040759  0.125627 -0.070651  0.054843
# LastRunSiteID       0.036718    0.040759  0.125627 -0.070651  0.054843
#
#                     AverageCPUTimeUsed  Used Memory  ReqNProcs   ReqTime  \
# JobID                         0.001529    -0.006505        NaN  0.228093
# SubmitTime                   -0.001129    -0.011825        NaN  0.239836
# WaitTime                      0.084616     0.053763        NaN -0.011237
# RunTime                       0.930096     0.153102        NaN  0.302292
# NProcs                        0.149645     0.201257        NaN  0.514302
# AverageCPUTimeUsed            1.000000     0.143072        NaN  0.305547
# Used Memory                   0.143072     1.000000        NaN  0.162100
# ReqNProcs                          NaN          NaN        NaN       NaN
# ReqTime                       0.305547     0.162100        NaN  1.000000
# ReqMemory                    -0.051844     0.411323        NaN -0.227886
# Status                       -0.114830    -0.102844        NaN -0.472877
# UserID                        0.000149     0.010112        NaN -0.072734
# GroupID                       0.053333     0.436112        NaN  0.654504
# ExecutableID                  0.128566     0.180504        NaN  0.468209
# QueueID                       0.290085    -0.068856        NaN  0.242554
# PartitionID                        NaN          NaN        NaN       NaN
# OrigSiteID                   -0.068569    -0.086098        NaN -0.151390
# LastRunSiteID                -0.068569    -0.086098        NaN -0.151390
#
#                     ReqMemory    Status    UserID   GroupID  ExecutableID  \
# JobID               -0.015313 -0.253427 -0.041675  0.166848      0.244308
# SubmitTime          -0.036476 -0.259337 -0.047152  0.173612      0.251795
# WaitTime             0.038418 -0.017893  0.050381  0.013633      0.015525
# RunTime             -0.051670 -0.130025 -0.005569  0.088784      0.129397
# NProcs               0.088099 -0.872220  0.255266  0.568508      0.945138
# AverageCPUTimeUsed  -0.051844 -0.114830  0.000149  0.053333      0.128566
# Used Memory          0.411323 -0.102844  0.010112  0.436112      0.180504
# ReqNProcs                 NaN       NaN       NaN       NaN           NaN
# ReqTime             -0.227886 -0.472877 -0.072734  0.654504      0.468209
# ReqMemory            1.000000 -0.013303  0.075850  0.051089      0.075675
# Status              -0.013303  1.000000 -0.210515 -0.511064     -0.830568
# UserID               0.075850 -0.210515  1.000000  0.015025      0.249590
# GroupID              0.051089 -0.511064  0.015025  1.000000      0.530940
# ExecutableID         0.075675 -0.830568  0.249590  0.530940      1.000000
# QueueID             -0.020154 -0.013240 -0.174425 -0.223635      0.037779
# PartitionID               NaN       NaN       NaN       NaN           NaN
# OrigSiteID           0.014427 -0.045325  0.313630 -0.100856      0.060474
# LastRunSiteID        0.014427 -0.045325  0.313630 -0.100856      0.060474
#
#                      QueueID  PartitionID  OrigSiteID  LastRunSiteID
# JobID              -0.024557          NaN    0.036718       0.036718
# SubmitTime         -0.019680          NaN    0.040759       0.040759
# WaitTime            0.002137          NaN    0.125627       0.125627
# RunTime             0.262011          NaN   -0.070651      -0.070651
# NProcs              0.045126          NaN    0.054843       0.054843
# AverageCPUTimeUsed  0.290085          NaN   -0.068569      -0.068569
# Used Memory        -0.068856          NaN   -0.086098      -0.086098
# ReqNProcs                NaN          NaN         NaN            NaN
# ReqTime             0.242554          NaN   -0.151390      -0.151390
# ReqMemory          -0.020154          NaN    0.014427       0.014427
# Status             -0.013240          NaN   -0.045325      -0.045325
# UserID             -0.174425          NaN    0.313630       0.313630
# GroupID            -0.223635          NaN   -0.100856      -0.100856
# ExecutableID        0.037779          NaN    0.060474       0.060474
# QueueID             1.000000          NaN   -0.168231      -0.168231
# PartitionID              NaN          NaN         NaN            NaN
# OrigSiteID         -0.168231          NaN    1.000000       1.000000
# LastRunSiteID      -0.168231          NaN    1.000000       1.000000

# %%
f, ax = plt.subplots(figsize=(15, 15)) 
heatmap = sns.heatmap(corr,
                      square = True,
                      linewidths = .5,
                      cmap = 'coolwarm',
                      cbar_kws = {'shrink': .4, 
                                'ticks' : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1, 
                      vmax = 1,
                      annot = True,
                      annot_kws = {"size": 12})
ax.set_yticklabels(corr.columns, rotation = 0)
ax.set_xticklabels(corr.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})
